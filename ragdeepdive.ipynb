# %%
print("ASritha")
# Out:
# ASritha

# %% [markdown]
# ****RAG BASICS****

# %%
#read the .env file and load the environment variables
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
#using langchain GoogleGenerativeAIEmbeddings
from langchain_google_genai import GoogleGenerativeAIEmbeddings
#Initializing the embedding model
embedding=GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")
#converted a random query into numerical vector using embedding model
vector=embedding.embed_query("What is RAG?")
print(vector)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\2406336\Downloads\RAG\.venv\Lib\site-packages\langchain_google_genai\embeddings.py:487, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     486 try:
# --> 487     result = self.client.models.embed_content(
#     488         model=self.model,
#     489         contents=text,
#     490         config=config,
#     491     )
#     492 except ClientError as e:
#
# File c:\Users\2406336\Downloads\RAG\.venv\Lib\site-packages\google\genai\models.py:6191, in Models.embed_content(self, model, contents, config)
#    6190     contents = t.t_contents(contents)  # type: ignore[assignment]
# -> 6191   return self._embed_content(model=model, contents=contents, config=config)
#    6193 if t.t_is_vertex_embed_content_model(model):
#
# ...
